# %% [markdown]
# <a href="https://colab.research.google.com/github/cfong32/key-sentence-extraction/blob/main/exp19_check_chatgptDS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import pandas as pd
from spacy.lang.en import English

# %%
# load dataset into a dataframe

# !wget -qO "Mohammad_dataset_result(3).json" https://uoguelphca-my.sharepoint.com/:u:/g/personal/mhavaled_uoguelph_ca/ET_4hgQABD5JhtiDtFGUG4gBASpIv6WURezHphMTlPCJqg?download=1
data = json.load(open('Mohammad_dataset_result(3).json'))
df = pd.DataFrame(data)
df
# Out:
#                                              paragraphs  \
# 0     Climate change is one of the most pressing iss...
# 1     Education is the key to unlocking a better fut...
# 2     The internet has revolutionized the way we com...
# 3     Mental health is just as important as physical...
# 4     Diversity and inclusion are essential for crea...
# ...                                                 ...
# 1255  Traveling is an enriching experience that allo...
# 1256  Mental health is crucial for our overall well-...
# 1257  Work is an essential part of our lives. It pro...
# 1258  The environment plays a critical role in our l...
# 1259  Family is an essential component of our lives....
#
#                                           key_sentences
# 0     We need to act urgently to reduce our greenhou...
# 1     It is crucial that we invest in education at a...
# 2     As we continue to rely on technology more and ...
# 3     It is crucial that we prioritize mental health...
# 4     It is important that we actively work to elimi...
# ...                                                 ...
# 1255  It can also be expensive, which may limit our ...
# 1256  It is important to seek help if you experience...
# 1257  In such cases, it can have a negative impact o...
# 1258  It is our responsibility to take care of the e...
# 1259  In such cases, it is important to communicate ...
#
# [1260 rows x 2 columns]

# %%
# split articles into sentences
# every entry of df['sentences'] will contain a list of strings

spacy_eng_nlp = English()
spacy_eng_nlp.add_pipe("sentencizer")

df['sentences'] = df.apply(
    lambda x: (
        [str(s) for s in spacy_eng_nlp(x.paragraphs).sents]
    ),
    axis=1
)
df
# Out:
#                                              paragraphs  \
# 0     Climate change is one of the most pressing iss...
# 1     Education is the key to unlocking a better fut...
# 2     The internet has revolutionized the way we com...
# 3     Mental health is just as important as physical...
# 4     Diversity and inclusion are essential for crea...
# ...                                                 ...
# 1255  Traveling is an enriching experience that allo...
# 1256  Mental health is crucial for our overall well-...
# 1257  Work is an essential part of our lives. It pro...
# 1258  The environment plays a critical role in our l...
# 1259  Family is an essential component of our lives....
#
#                                           key_sentences  \
# 0     We need to act urgently to reduce our greenhou...
# 1     It is crucial that we invest in education at a...
# 2     As we continue to rely on technology more and ...
# 3     It is crucial that we prioritize mental health...
# 4     It is important that we actively work to elimi...
# ...                                                 ...
# 1255  It can also be expensive, which may limit our ...
# 1256  It is important to seek help if you experience...
# 1257  In such cases, it can have a negative impact o...
# 1258  It is our responsibility to take care of the e...
# 1259  In such cases, it is important to communicate ...
#
#                                               sentences
# 0     [Climate change is one of the most pressing is...
# 1     [Education is the key to unlocking a better fu...
# 2     [The internet has revolutionized the way we co...
# 3     [Mental health is just as important as physica...
# 4     [Diversity and inclusion are essential for cre...
# ...                                                 ...
# 1255  [Traveling is an enriching experience that all...
# 1256  [Mental health is crucial for our overall well...
# 1257  [Work is an essential part of our lives., It p...
# 1258  [The environment plays a critical role in our ...
# 1259  [Family is an essential component of our lives...
#
# [1260 rows x 3 columns]

# %%
# indicate which is the key sentence

df['is_key'] = df.apply(
    lambda x: (
        [int(x.key_sentences in s) for s in x.sentences]
    ),
    axis=1
)
df
# Out:
#                                              paragraphs  \
# 0     Climate change is one of the most pressing iss...
# 1     Education is the key to unlocking a better fut...
# 2     The internet has revolutionized the way we com...
# 3     Mental health is just as important as physical...
# 4     Diversity and inclusion are essential for crea...
# ...                                                 ...
# 1255  Traveling is an enriching experience that allo...
# 1256  Mental health is crucial for our overall well-...
# 1257  Work is an essential part of our lives. It pro...
# 1258  The environment plays a critical role in our l...
# 1259  Family is an essential component of our lives....
#
#                                           key_sentences  \
# 0     We need to act urgently to reduce our greenhou...
# 1     It is crucial that we invest in education at a...
# 2     As we continue to rely on technology more and ...
# 3     It is crucial that we prioritize mental health...
# 4     It is important that we actively work to elimi...
# ...                                                 ...
# 1255  It can also be expensive, which may limit our ...
# 1256  It is important to seek help if you experience...
# 1257  In such cases, it can have a negative impact o...
# 1258  It is our responsibility to take care of the e...
# 1259  In such cases, it is important to communicate ...
#
#                                               sentences           is_key
# 0     [Climate change is one of the most pressing is...     [0, 0, 0, 1]
# 1     [Education is the key to unlocking a better fu...     [0, 0, 0, 1]
# 2     [The internet has revolutionized the way we co...        [0, 0, 1]
# 3     [Mental health is just as important as physica...        [0, 0, 1]
# 4     [Diversity and inclusion are essential for cre...        [0, 0, 1]
# ...                                                 ...              ...
# 1255  [Traveling is an enriching experience that all...     [0, 0, 0, 1]
# 1256  [Mental health is crucial for our overall well...  [0, 0, 0, 0, 1]
# 1257  [Work is an essential part of our lives., It p...     [0, 0, 0, 1]
# 1258  [The environment plays a critical role in our ...     [0, 0, 0, 1]
# 1259  [Family is an essential component of our lives...  [0, 0, 0, 0, 1]
#
# [1260 rows x 4 columns]

# %%
# show all "single-sentence" paragraphs

df[df.is_key.apply(len) == 1]
# Out:
#                                             paragraphs  \
# 77   The impacts of climate change include rising t...
# 81   Individual actions, such as reducing energy co...
# 87   Investing in education also has positive impac...
# 91   Governments and organizations around the world...
# 92   The pandemic has also highlighted existing ine...
# 94   The pandemic has also accelerated trends such ...
# 95   The COVID-19 pandemic has also led to unpreced...
# 99   Addressing climate change requires a range of ...
# 115  To address this challenge, researchers are exp...
# 122  To address these concerns, researchers are exp...
# 124  In conclusion, AI offers many potential benefi...
# 127  To mitigate the effects of global warming, the...
# 128  Individuals can also take actions to reduce th...
# 135  However, there are also concerns about the pot...
# 138  In conclusion, AI has the potential to revolut...
# 140  The impacts of climate change are already bein...
#
#                                          key_sentences  \
# 77   The impacts of climate change include rising t...
# 81   Individual actions, such as reducing energy co...
# 87   Investing in education also has positive impac...
# 91   Governments and organizations around the world...
# 92   The pandemic has also highlighted existing ine...
# 94   The pandemic has also accelerated trends such ...
# 95   The COVID-19 pandemic has also led to unpreced...
# 99   Addressing climate change requires a range of ...
# 115  To address this challenge, researchers are exp...
# 122  To address these concerns, researchers are exp...
# 124  In conclusion, AI offers many potential benefi...
# 127  To mitigate the effects of global warming, the...
# 128  Individuals can also take actions to reduce th...
# 135  However, there are also concerns about the pot...
# 138  In conclusion, AI has the potential to revolut...
# 140  The impacts of climate change are already bein...
#
#                                              sentences is_key
# 77   [The impacts of climate change include rising ...    [1]
# 81   [Individual actions, such as reducing energy c...    [1]
# 87   [Investing in education also has positive impa...    [1]
# 91   [Governments and organizations around the worl...    [1]
# 92   [The pandemic has also highlighted existing in...    [1]
# 94   [The pandemic has also accelerated trends such...    [1]
# 95   [The COVID-19 pandemic has also led to unprece...    [1]
# 99   [Addressing climate change requires a range of...    [1]
# 115  [To address this challenge, researchers are ex...    [1]
# 122  [To address these concerns, researchers are ex...    [1]
# 124  [In conclusion, AI offers many potential benef...    [1]
# 127  [To mitigate the effects of global warming, th...    [1]
# 128  [Individuals can also take actions to reduce t...    [1]
# 135  [However, there are also concerns about the po...    [1]
# 138  [In conclusion, AI has the potential to revolu...    [1]
# 140  [The impacts of climate change are already bei...    [1]

# %%
# show all paragraphs which cannot locate one and only one key sentence

df[df.is_key.apply(sum)!=1]
# Out:
#                                              paragraphs  \
# 1088  The development of AI has also raised ethical ...
#
#                                           key_sentences  \
# 1088  For example, can AI have consciousness and emo...
#
#                                               sentences        is_key
# 1088  [The development of AI has also raised ethical...  [0, 0, 0, 0]

# %%
# show paragraph #1088

x = df.loc[1088]
x.paragraphs
# Out:
# 'The development of AI has also raised ethical and philosophical questions. For example, can AI have consciousness and emotions like humans? Should we grant AI legal personhood? Moreover, some experts warn that the development of super AI could pose an existential threat to humanity.'

# %%
x.sentences
# Out:
# ['The development of AI has also raised ethical and philosophical questions.',
#  'For example, can AI have consciousness and emotions like humans?',
#  'Should we grant AI legal personhood?',
#  'Moreover, some experts warn that the development of super AI could pose an existential threat to humanity.']

# %%
x.key_sentences
# Out:
# 'For example, can AI have consciousness and emotions like humans? Should we grant AI legal personhood? Moreover, some experts warn that the development of super AI could pose an existential threat to humanity.'
